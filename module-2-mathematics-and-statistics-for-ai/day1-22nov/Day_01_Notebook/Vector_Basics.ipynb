# %% [markdown]
# \# Practical Linear Algebra for Data Science
#
#
# #### Code for Vectors

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt


# NOTE: these lines define global figure properties used for publication.
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg') # display figures in vector format
plt.rcParams.update({'font.size':14}) # set global font size

# %% [markdown]
# # Creating vectors

# %%
# a vector as a Python list datatype
asList = [1,2,3]

# same numbers, but as a dimensionless numpy array
asArray = np.array([1,2,3])

# again same numbers, but now endowed with orientations
rowVec = np.array([ [1,2,3] ]) # row
colVec = np.array([ [1],[2],[3] ]) # column

# %%
asList
# Out:
# [1, 2, 3]

# %%
asList.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2170137990.py in <cell line: 0>()
# ----> 1 asList.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
asArray
# Out:
# array([1, 2, 3])

# %%
asArray.shape
# Out:
# (3,)

# %%
rowVec
# Out:
# array([[1, 2, 3]])

# %%
rowVec.shape
# Out:
# (1, 3)

# %%
colVec
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
colVec.shape
# Out:
# (3, 1)

# %%
# Check the sizes of the variables
print(f'asList:  {np.shape(asList)}') # using np's shape function
print(f'asArray: {asArray.shape}') # using a method associated with numpy objects
print(f'rowVec:  {rowVec.shape}')
print(f'colVec:  {colVec.shape}')
# Out:
# asList:  (3,)
# asArray: (3,)
# rowVec:  (1, 3)
# colVec:  (3, 1)

# %% [markdown]
# # Geometry of vectors

# %%
# create a vector
v = np.array([-1,2])

# plot that vector (and a dot for the tail)
plt.arrow(0,0,v[0],v[1],head_width=.5,width=.1)

plt.plot(0,0,'ko',markerfacecolor='k',markersize=7)

# add axis lines
plt.plot([-3,3],[0,0],'--',color=[.8,.8,.8],zorder=-1)
plt.plot([0,0],[-3,3],'--',color=[.8,.8,.8],zorder=-1)

# make the plot look nicer
plt.axis('square')
plt.axis([-3,3,-3,3])
plt.xlabel('$v_0$')
plt.ylabel('$v_1$')
plt.title('Vector v in standard position')
plt.show()

# %% [markdown]
# # Adding vectors

# %%
# Using 2D vectors here instead of 3D vectors to facilitate visualization
v = np.array([1,2])
w = np.array([4,-6])
vPlusW = v+w

# print out all three vectors
print(v)
print(w)
print(vPlusW)
# Out:
# [1 2]
# [ 4 -6]
# [ 5 -4]

# %%
v.shape
# Out:
# (2,)

# %% [markdown]
# ### Adding vectors with different dimensions

# %%
import numpy as np

# Define two row vectors with different dimensions
vector1 = np.array([[1, 2, 3]])  # 1x3 row vector
vector2 = np.array([[4]])     # 1x2 row vector

try:
    # Attempt to add the vectors
    result = vector1 + vector2
    print("Result:", result)
except ValueError as e:
    # Catch and print the error
    print("Error:", e)
# Out:
# Result: [[5 6 7]]

# %% [markdown]
# # Subtracting vectors

# %%
# Same v and w as above for comparison
vMinusW = v-w

# print out all three vectors
print(v)
print(w)
print(vMinusW)
# Out:
# [1 2]
# [ 4 -6]
# [-3  8]

# %% [markdown]
# ## Vector Broadcasting

# %%
vector1 = np.array([[1, 2, 3]])  # Shape: (1, 3) - Row vector
vector2 = np.array([[10],        # Shape: (3, 1) - Column vector
                    [20],
                    [30]])

result = vector1 + vector2

# %%
result
# Out:
# array([[11, 12, 13],
#        [21, 22, 23],
#        [31, 32, 33]])

# %% [markdown]
# # Vector-scalar multiplication

# %%
# a scalar
s = -1/2

# a vector
b = np.array([3,4])

# print them
print(b*s)

# Question: Does vector b need to be a numpy array? What happens if it's a list?
# Out:
# [-1.5 -2. ]

# %%
# a scalar
s = 1/2

# a vector
c = [3,4]

# print(c*s)

# %%
# Scalar-vector addition
s = 3.5

print(v)
print(s+v)
# Out:
# [1 2]
# [4.5 5.5]

# %%
v=np.array([3,4])+10
v
# Out:
# array([13, 14])

# %%
[3,4]+[10]
# Out:
# [3, 4, 10]

# %% [markdown]
# # Vector transpose
#
#
# *   It converts column vectors into row vectors, and vice versa

# %%
# Row vector
r = np.array([ [1,2,3] ])

# orientationless array
l = np.array([1,2,3])

# %%
# print out the vector, its transpose, and its double-transpose
print(r), print(' ')

# Transpose the row vector
print(r.T), print(' ')

# double-transpose
print(r.T.T)
# Out:
# [[1 2 3]]
#
# [[1]
#  [2]
#  [3]]
#
# [[1 2 3]]

# %%
# Same for the orientationless array
print(l), print(' ')
print(l.T), print(' ')
print(l.T.T)
# Out:
# [1 2 3]
#
# [1 2 3]
#
# [1 2 3]

# %% [markdown]
# # Norm of the vector

# %%
import numpy as np

# Define a vector
vector = np.array([3, 4])

# Calculate the Euclidean norm
norm = np.linalg.norm(vector)

print("Vector:", vector)
print("Euclidean Norm:", norm)
# Out:
# Vector: [3 4]
# Euclidean Norm: 5.0

# %%
import numpy as np

# Define a vector
vector = np.array([3, 4])

# Calculate the magnitude
magnitude = np.linalg.norm(vector,ord=3)

# Calculate the unit vector
unit_vector = vector / magnitude

print("Original Vector:", vector)
print("Magnitude:", magnitude)
print("Unit Vector:", unit_vector)
# Out:
# Original Vector: [3 4]
# Magnitude: 4.497941445275415
# Unit Vector: [0.66697178 0.8892957 ]

# %% [markdown]
# # The Vector Dot Product

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# Define two vectors
vector_a = np.array([1, 2, 3])
vector_b = np.array([4, 5, 6])

# Compute the dot product
dot_product = np.dot(vector_a, vector_b)

print("Vector A:", vector_a)
print("Vector B:", vector_b)
print("Dot Product:", dot_product)
# Out:
# Vector A: [1 2 3]
# Vector B: [4 5 6]
# Dot Product: 32

# %%
import numpy as np

# Define two vectors of different lengths
vector_a = np.array([1, 2, 3])
vector_b = np.array([4, 5])

try:
    # Attempt to compute the dot product
    dot_product = np.dot(vector_a, vector_b)
    print("Dot Product:", dot_product)
except ValueError as e:
    # Catch and display the error
    print("Error:", e)
# Out:
# Error: shapes (3,) and (2,) not aligned: 3 (dim 0) != 2 (dim 0)

# %% [markdown]
# # The dot product is distributive

# %%
# just some random vectors...
v = np.array([ 0,1,2 ])
w = np.array([ 3,5,8 ])
u = np.array([ 13,21,34 ])

# two ways to comptue
res1 = np.dot( v, w+u )
res2 = np.dot( v,w ) + np.dot( v,u )

# show that they are equivalent
res1,res2
# Out:
# (np.int64(110), np.int64(110))
