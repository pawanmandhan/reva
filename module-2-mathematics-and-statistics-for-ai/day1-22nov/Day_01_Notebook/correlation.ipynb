# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/drive/MyDrive/Linear_Algebra/auto-mpg.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv('/content/drive/MyDrive/Linear_Algebra/auto-mpg.csv')
#
# File c:\Users\Pawan\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.shape
# Out:
# (398, 9)

# %%
data=df[["mpg","cylinders","displacement","weight"]]

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  weight
# 0  18.0          8         307.0    3504
# 1  15.0          8         350.0    3693
# 2  18.0          8         318.0    3436
# 3  16.0          8         304.0    3433
# 4  17.0          8         302.0    3449

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   weight        398 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 12.6 KB

# %%
def correlation(col1,col2):
  mean1=np.mean(col1)
  mean2=np.mean(col2)
  new_col1=col1-mean1
  new_col2=col2-mean2
  numerator =np.dot(new_col1,new_col2)
  denominator= np.linalg.norm(new_col1)*np.linalg.norm(new_col2)
  return numerator/denominator

# %%
correlation(data["mpg"],data["weight"])
# Out:
# np.float64(-0.8317409332443346)

# %%
correlation(data["cylinders"],data["weight"])
# Out:
# np.float64(0.8960167954533946)

# %%
data.corr()
# Out:
#                    mpg  cylinders  displacement    weight
# mpg           1.000000  -0.775396     -0.804203 -0.831741
# cylinders    -0.775396   1.000000      0.950721  0.896017
# displacement -0.804203   0.950721      1.000000  0.932824
# weight       -0.831741   0.896017      0.932824  1.000000

# %%
jupyter kernelspec list
# Out:
#   Cell In[4], line 1
#     jupyter kernelspec list
#             ^
# SyntaxError: invalid syntax
